# %%
import pandas as pd

df = pd.read_csv('Data/arc.csv')

df = df.drop(['name', 'version', 'name.1'], axis=1)

df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  234.000000  234.000000  234.000000  234.000000  234.000000
# mean     9.226496    1.568376    0.162393    7.559829   21.303419
# std      9.156483    1.102876    1.596441    8.860788   26.423057
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      3.000000    1.000000    0.000000    3.000000    5.250000
# 50%      6.000000    1.000000    0.000000    5.000000   14.000000
# 75%     13.000000    1.000000    0.000000    8.000000   25.000000
# max     55.000000    5.000000   23.000000   74.000000  166.000000
#
#               lcom          ca          ce         npm       lcom3  ...  \
# count   234.000000  234.000000  234.000000  234.000000  234.000000  ...
# mean     56.158120    2.893162    4.705128    8.572650    1.328542  ...
# std     138.678483    6.628825    6.490883    8.550096    0.614953  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
zeroes = 0
ones = 0

for i in range(len(df['bug'])):
    if df['bug'][i] != 0:  ones += 1
    else: zeroes += 1
    
print('zeros: ', zeroes, ' | Ones: ', ones)
# Out:
# zeros:  207  | Ones:  27

# %%
ones*100/zeroes
# Out:
# 13.043478260869565
